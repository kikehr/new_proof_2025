# %% [markdown]
# # 1- intro tu mlflow I

# %%
import mlflow

# %% [markdown]
# #### 2-conectarse a servidor

# %%
MLFLOW_TRACKING_URI = "http://127.0.0.1:5000"
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# %%
#comprobar si esta todo correcto 
experiments = mlflow.search_experiments()

# %%
#indica ubicacion de artefactos 
experiments
# Out:
# [<Experiment: artifact_location='mlflow-artifacts:/785922938838006357', creation_time=1749659471264, experiment_id='785922938838006357', last_update_time=1749659471264, lifecycle_stage='active', name='PRUEBA11625', tags={}>,
#  <Experiment: artifact_location='mlflow-artifacts:/0', creation_time=1749634634788, experiment_id='0', last_update_time=1749634634788, lifecycle_stage='active', name='Default', tags={}>]

# %% [markdown]
# ### CONECT TO EXPERIMENT

# %%
EXPERIMENT_NAME = "PRUEBA11625"
mlflow.set_experiment(EXPERIMENT_NAME)
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/785922938838006357', creation_time=1749659471264, experiment_id='785922938838006357', last_update_time=1749659471264, lifecycle_stage='active', name='PRUEBA11625', tags={}>

# %% [markdown]
# #### create my first run

# %%
with mlflow.start_run():
    pass
# Out:
# 🏃 View run omniscient-tern-326 at: http://127.0.0.1:5000/#/experiments/785922938838006357/runs/9b7b772242794c71bb7d4bb2141b45ac
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/785922938838006357

# %% [markdown]
# #### log data into mlflow

# %%
with mlflow.start_run():
    mlflow.set_tag("model name", "Decision tree")
    mlflow.set_tag("author","kike herruiz")
# Out:
# 🏃 View run sassy-perch-569 at: http://127.0.0.1:5000/#/experiments/785922938838006357/runs/d338ddb510d14b939af633bcfc7bca50
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/785922938838006357

# %% [markdown]
# #### log parameters

# %%
with mlflow.start_run():
    mlflow.log_param("size", "0.2")
# Out:
# 🏃 View run whimsical-lynx-26 at: http://127.0.0.1:5000/#/experiments/785922938838006357/runs/97d7ff2fefa04ff38e0a131d74f874d5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/785922938838006357

# %% [markdown]
# #### log metrics

# %%
with mlflow.start_run():
    mlflow.log_metric("accuracy", 0.95)
# Out:
# 🏃 View run skittish-worm-780 at: http://127.0.0.1:5000/#/experiments/785922938838006357/runs/4cc7451343f04857bfe0b6390d8bf7e2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/785922938838006357

# %% [markdown]
# ### entrenamiento basico con mlflow

# %%
with mlflow.start_run():
    mlflow.set_tag("author", "kike")
    mlflow.log_param("size", "0.2")
    #train your model
    #model.fit(X_train, y_train)
    #y_pred = model.predict(X_test)
    #acc = accuracy_score(y_test, y_pred)
    acc=0.95
    mlflow.log_metric("accuracy", acc)
# Out:
# 🏃 View run receptive-wasp-172 at: http://127.0.0.1:5000/#/experiments/785922938838006357/runs/8b5501cbbce642e090c27b1a77028c4a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/785922938838006357
